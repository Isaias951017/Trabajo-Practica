# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from config.settings import DB_CONNECTION_STRING

# %%
import pandas as pd
from sqlalchemy import create_engine, text
from config.settings import DB_CONNECTION_STRING
import plotly.express as px

# Leer el archivo SQL
with open("../sql_queries/queries.sql", "r", encoding="utf-8") as file:
    query = file.read()

# Parámetros para la consulta
params = {
    "medico": "PSICOLOGÍA",
    "fechaini": "2023-01-01",
    "fechafin": "2025-05-04"
}

# Crear conexión y ejecutar
engine = create_engine(DB_CONNECTION_STRING)
with engine.connect() as conn:
    historias_clinicas = pd.read_sql(text(query), conn, params=params)

historias_clinicas=historias_clinicas.head(5000)

# %%
type(historias_clinicas)
# Out:
# pandas.core.frame.DataFrame

# %%
#dimennsiones
dimensiones=historias_clinicas.shape
print(dimensiones)
# Out:
# (5000, 6)

# %%
historias_clinicas.dtypes
# Out:
# SEXO                   object
# EDAD                    int64
# GRUPO                  object
# ESPECIALIDAD_MEDICA    object
# SUBJETIVO              object
# OBJETIVO               object
# dtype: object

# %%
historias_clinicas.describe(include="all").T
# Out:
#                       count unique  \
# SEXO                   5000      2
# EDAD                 5000.0    NaN
# GRUPO                  5000      6
# ESPECIALIDAD_MEDICA    5000      1
# SUBJETIVO              4855   4679
# OBJETIVO               4894   3135
#
#                                                                    top  freq  \
# SEXO                                                          Femenino  3391
# EDAD                                                               NaN   NaN
# GRUPO                                                   T. de Ansiedad  1588
# ESPECIALIDAD_MEDICA                                         PSICOLOGÍA  5000
# SUBJETIVO                                                                 11
# OBJETIVO             Alerta, actitud adecuada, orientación en tiemp...   124
#
#                         mean        std  min   25%   50%   75%   max
# SEXO                     NaN        NaN  NaN   NaN   NaN   NaN   NaN
# EDAD                 32.3472  18.333725  1.0  17.0  28.0  45.0  92.0
# GRUPO                    NaN        NaN  NaN   NaN   NaN   NaN   NaN
# ESPECIALIDAD_MEDICA      NaN        NaN  NaN   NaN   NaN   NaN   NaN
# SUBJETIVO                NaN        NaN  NaN   NaN   NaN   NaN   NaN
# OBJETIVO                 NaN        NaN  NaN   NaN   NaN   NaN   NaN

# %%
historias_clinicas["GRUPO"]=historias_clinicas["GRUPO"].str.capitalize()

# %%
#Nulos
historias_clinicas.isnull().sum()
# Out:
# SEXO                     0
# EDAD                     0
# GRUPO                    0
# ESPECIALIDAD_MEDICA      0
# SUBJETIVO              145
# OBJETIVO               106
# dtype: int64

# %%
#Concatener columnas
historias_clinicas["Concatenada"] = historias_clinicas["SUBJETIVO"].astype(str) + " " + historias_clinicas["OBJETIVO"].astype(str)

# %%
historias_clinicas
# Out:
#            SEXO  EDAD               GRUPO ESPECIALIDAD_MEDICA  \
# 0      Femenino    38    Otros trastornos          PSICOLOGÍA
# 1     Masculino    22  T. externalizantes          PSICOLOGÍA
# 2     Masculino     9    Otros trastornos          PSICOLOGÍA
# 3     Masculino    28    Otros trastornos          PSICOLOGÍA
# 4      Femenino     8    Otros trastornos          PSICOLOGÍA
# ...         ...   ...                 ...                 ...
# 4995   Femenino    20       T. depresivos          PSICOLOGÍA
# 4996  Masculino    41       T. depresivos          PSICOLOGÍA
# 4997   Femenino    37    Otros trastornos          PSICOLOGÍA
# 4998   Femenino    18      T. de ansiedad          PSICOLOGÍA
# 4999   Femenino    15    Otros trastornos          PSICOLOGÍA
#
#                                               SUBJETIVO  \
# 0     Paciente refiere: "Me empezaron a dar como uno...
# 1     Paciente refiere "Me he sentido muy mal, en el...
# 2     La madre refiere "el viene por un acompañamien...
# 3     Paciente refiere "Estas cosas que han pasado m...
# 4     La madre refiere "Ella ha manifestado ciertas ...
# ...                                                 ...
# 4995  La paciente refiere: "Digamos que mejorando, s...
# 4996  SEGUIMIENTO: El paciente expresa "me siento mu...
# 4997  La paciente refiere "el día 28 de diciembre me...
# 4998  La acudiente refiere: "Ella va bien, con mucha...
# 4999  Madre de la paciente refiere: "Ella va a tener...
#
#                                                OBJETIVO  \
# 0     Paciente alerta, colaboradora con apariencia o...
# 1     Paciente a quien evaluó por primera vez, alert...
# 2                                                  None
# 3     Paciente quien evalúo por primera vez, alerta,...
# 4     Paciente ingresa en compañía de la madre, aler...
# ...                                                 ...
# 4995  Paciente alerta, colaboradora con apariencia o...
# 4996  Paciente quien evalúo por primera vez, orienta...
# 4997  Paciente quien evalúo por teleconsulta, se evi...
# 4998  Paciente alerta, colaboradora con apariencia o...
# 4999  Paciente alerta, colaboradora con apariencia o...
#
#                                             Concatenada
# 0     Paciente refiere: "Me empezaron a dar como uno...
# 1     Paciente refiere "Me he sentido muy mal, en el...
# 2     La madre refiere "el viene por un acompañamien...
# 3     Paciente refiere "Estas cosas que han pasado m...
# 4     La madre refiere "Ella ha manifestado ciertas ...
# ...                                                 ...
# 4995  La paciente refiere: "Digamos que mejorando, s...
# 4996  SEGUIMIENTO: El paciente expresa "me siento mu...
# 4997  La paciente refiere "el día 28 de diciembre me...
# 4998  La acudiente refiere: "Ella va bien, con mucha...
# 4999  Madre de la paciente refiere: "Ella va a tener...
#
# [5000 rows x 7 columns]

# %%
#Información
historias_clinicas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SEXO                 5000 non-null   object
#  1   EDAD                 5000 non-null   int64
#  2   GRUPO                5000 non-null   object
#  3   ESPECIALIDAD_MEDICA  5000 non-null   object
#  4   SUBJETIVO            4855 non-null   object
#  5   OBJETIVO             4894 non-null   object
#  6   Concatenada          5000 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 273.6+ KB

# %%
#Ditribución de hc por sexo
historias_clinicas["SEXO"].value_counts()
px.histogram(historias_clinicas, 
             x="SEXO", 
             title="Distribución de Sexo en Historias Clínicas", 
             color="SEXO",
             text_auto=True)

# %%
#histrograma de edad
px.histogram(historias_clinicas, 
             x="EDAD", 
             title="Distribución de Edad en Historias Clínicas", 
            text_auto=True)

# %%
#Distribución de HC por edad y sexo
px.histogram(historias_clinicas, 
             x="EDAD", 
             title="Distribución de Edad en Historias Clínicas por Sexo", 
             color="SEXO",
             text_auto=True)

# %%
px.histogram(
    historias_clinicas,
    x="GRUPO",
    title="Distribución de Historias Clínicas por Grupo",
    color="GRUPO",
    text_auto=True
)

# %%
historias_clinicas
# Out:
#            SEXO  EDAD               GRUPO ESPECIALIDAD_MEDICA  \
# 0      Femenino    38    Otros trastornos          PSICOLOGÍA
# 1     Masculino    22  T. externalizantes          PSICOLOGÍA
# 2     Masculino     9    Otros trastornos          PSICOLOGÍA
# 3     Masculino    28    Otros trastornos          PSICOLOGÍA
# 4      Femenino     8    Otros trastornos          PSICOLOGÍA
# ...         ...   ...                 ...                 ...
# 4995   Femenino    20       T. depresivos          PSICOLOGÍA
# 4996  Masculino    41       T. depresivos          PSICOLOGÍA
# 4997   Femenino    37    Otros trastornos          PSICOLOGÍA
# 4998   Femenino    18      T. de ansiedad          PSICOLOGÍA
# 4999   Femenino    15    Otros trastornos          PSICOLOGÍA
#
#                                               SUBJETIVO  \
# 0     Paciente refiere: "Me empezaron a dar como uno...
# 1     Paciente refiere "Me he sentido muy mal, en el...
# 2     La madre refiere "el viene por un acompañamien...
# 3     Paciente refiere "Estas cosas que han pasado m...
# 4     La madre refiere "Ella ha manifestado ciertas ...
# ...                                                 ...
# 4995  La paciente refiere: "Digamos que mejorando, s...
# 4996  SEGUIMIENTO: El paciente expresa "me siento mu...
# 4997  La paciente refiere "el día 28 de diciembre me...
# 4998  La acudiente refiere: "Ella va bien, con mucha...
# 4999  Madre de la paciente refiere: "Ella va a tener...
#
#                                                OBJETIVO  \
# 0     Paciente alerta, colaboradora con apariencia o...
# 1     Paciente a quien evaluó por primera vez, alert...
# 2                                                  None
# 3     Paciente quien evalúo por primera vez, alerta,...
# 4     Paciente ingresa en compañía de la madre, aler...
# ...                                                 ...
# 4995  Paciente alerta, colaboradora con apariencia o...
# 4996  Paciente quien evalúo por primera vez, orienta...
# 4997  Paciente quien evalúo por teleconsulta, se evi...
# 4998  Paciente alerta, colaboradora con apariencia o...
# 4999  Paciente alerta, colaboradora con apariencia o...
#
#                                             Concatenada
# 0     Paciente refiere: "Me empezaron a dar como uno...
# 1     Paciente refiere "Me he sentido muy mal, en el...
# 2     La madre refiere "el viene por un acompañamien...
# 3     Paciente refiere "Estas cosas que han pasado m...
# 4     La madre refiere "Ella ha manifestado ciertas ...
# ...                                                 ...
# 4995  La paciente refiere: "Digamos que mejorando, s...
# 4996  SEGUIMIENTO: El paciente expresa "me siento mu...
# 4997  La paciente refiere "el día 28 de diciembre me...
# 4998  La acudiente refiere: "Ella va bien, con mucha...
# 4999  Madre de la paciente refiere: "Ella va a tener...
#
# [5000 rows x 7 columns]
