# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from config.settings import DB_CONNECTION_STRING

# %%
import pandas as pd
from sqlalchemy import create_engine, text
from config.settings import DB_CONNECTION_STRING
import plotly.express as px

# Leer el archivo SQL
with open("../sql_queries/queries.sql", "r", encoding="utf-8") as file:
    query = file.read()

# Parámetros para la consulta
params = {
    "medico": "PSICOLOGÍA",
    "fechaini": "2023-01-01",
    "fechafin": "2025-05-04"
}

# Crear conexión y ejecutar
engine = create_engine(DB_CONNECTION_STRING)
with engine.connect() as conn:
    historias_clinicas = pd.read_sql(text(query), conn, params=params)

historias_clinicas=historias_clinicas.head(3000)

# %%
type(historias_clinicas)
# Out:
# pandas.core.frame.DataFrame

# %%
#dimennsiones
dimensiones=historias_clinicas.shape
print(dimensiones)
# Out:
# (3000, 7)

# %%
historias_clinicas.dtypes
# Out:
# SEXO                   object
# EDAD                    int64
# GRUPO                  object
# ESPECIALIDAD_MEDICA    object
# SUBJETIVO              object
# OBJETIVO               object
# Concatenada            object
# dtype: object

# %%
historias_clinicas.describe(include="all").T
# Out:
#                       count unique  \
# SEXO                   3000      2
# EDAD                 3000.0    NaN
# GRUPO                  3000      6
# ESPECIALIDAD_MEDICA    3000      1
# SUBJETIVO              2907   2780
# OBJETIVO               2946   1909
# Concatenada            3000   2858
#
#                                                                    top  freq  \
# SEXO                                                          Femenino  2019
# EDAD                                                               NaN   NaN
# GRUPO                                                   T. de Ansiedad   857
# ESPECIALIDAD_MEDICA                                         PSICOLOGÍA  3000
# SUBJETIVO                                                                 11
# OBJETIVO             Alerta, actitud adecuada, orientación en tiemp...   105
# Concatenada                                                               37
#
#                           mean        std  min   25%   50%   75%   max
# SEXO                       NaN        NaN  NaN   NaN   NaN   NaN   NaN
# EDAD                 33.360667  18.300607  1.0  18.0  30.0  45.0  92.0
# GRUPO                      NaN        NaN  NaN   NaN   NaN   NaN   NaN
# ESPECIALIDAD_MEDICA        NaN        NaN  NaN   NaN   NaN   NaN   NaN
# SUBJETIVO                  NaN        NaN  NaN   NaN   NaN   NaN   NaN
# OBJETIVO                   NaN        NaN  NaN   NaN   NaN   NaN   NaN
# Concatenada                NaN        NaN  NaN   NaN   NaN   NaN   NaN

# %%
historias_clinicas["GRUPO"]=historias_clinicas["GRUPO"].str.capitalize()

# %%
#Nulos
historias_clinicas.isnull().sum()
# Out:
# SEXO                    0
# EDAD                    0
# GRUPO                   0
# ESPECIALIDAD_MEDICA     0
# SUBJETIVO              93
# OBJETIVO               54
# Concatenada             0
# dtype: int64

# %%
#Concatener columnas
historias_clinicas["Concatenada"] = historias_clinicas["SUBJETIVO"].astype(str) + " " + historias_clinicas["OBJETIVO"].astype(str)

# %%
historias_clinicas
# Out:
#            SEXO  EDAD               GRUPO ESPECIALIDAD_MEDICA  \
# 0      Femenino    38    Otros trastornos          PSICOLOGÍA
# 1     Masculino    22  T. externalizantes          PSICOLOGÍA
# 2     Masculino     9    Otros trastornos          PSICOLOGÍA
# 3     Masculino    28    Otros trastornos          PSICOLOGÍA
# 4      Femenino     8    Otros trastornos          PSICOLOGÍA
# ...         ...   ...                 ...                 ...
# 2995  Masculino    29    Otros trastornos          PSICOLOGÍA
# 2996   Femenino    55       T. depresivos          PSICOLOGÍA
# 2997  Masculino     9     T. personalidad          PSICOLOGÍA
# 2998  Masculino    57    Otros trastornos          PSICOLOGÍA
# 2999  Masculino    57    Otros trastornos          PSICOLOGÍA
#
#                                               SUBJETIVO  \
# 0     Paciente refiere: "Me empezaron a dar como uno...
# 1     Paciente refiere "Me he sentido muy mal, en el...
# 2     La madre refiere "el viene por un acompañamien...
# 3     Paciente refiere "Estas cosas que han pasado m...
# 4     La madre refiere "Ella ha manifestado ciertas ...
# ...                                                 ...
# 2995  \n"yo estoy muy bien, no he vuelto a consumir,...
# 2996  Reporta dificultades de sueño, a pesar de toma...
# 2997  Paciente refiere:\n"A veces no controlo lo que...
# 2998  ‘’Lo mío es bastante duro, porque la enfermeda...
# 2999  La esposa Nubia Arroyave refiere:\n"En ocasion...
#
#                                                OBJETIVO  \
# 0     Paciente alerta, colaboradora con apariencia o...
# 1     Paciente a quien evaluó por primera vez, alert...
# 2                                                  None
# 3     Paciente quien evalúo por primera vez, alerta,...
# 4     Paciente ingresa en compañía de la madre, aler...
# ...                                                 ...
# 2995  \nToxicológicos: Marihuana y Perico hace 15 añ...
# 2996  Alerta, actitud adecuada, orientación en tiemp...
# 2997  Se realiza cita en la modalidad: Teleconsulta,...
# 2998  Paciente quien evalúo por primera vez, con bas...
# 2999  Alerta, actitud colabora en la entrevista, ori...
#
#                                             Concatenada
# 0     Paciente refiere: "Me empezaron a dar como uno...
# 1     Paciente refiere "Me he sentido muy mal, en el...
# 2     La madre refiere "el viene por un acompañamien...
# 3     Paciente refiere "Estas cosas que han pasado m...
# 4     La madre refiere "Ella ha manifestado ciertas ...
# ...                                                 ...
# 2995  \n"yo estoy muy bien, no he vuelto a consumir,...
# 2996  Reporta dificultades de sueño, a pesar de toma...
# 2997  Paciente refiere:\n"A veces no controlo lo que...
# 2998  ‘’Lo mío es bastante duro, porque la enfermeda...
# 2999  La esposa Nubia Arroyave refiere:\n"En ocasion...
#
# [3000 rows x 7 columns]

# %%
#Información
historias_clinicas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SEXO                 3000 non-null   object
#  1   EDAD                 3000 non-null   int64
#  2   GRUPO                3000 non-null   object
#  3   ESPECIALIDAD_MEDICA  3000 non-null   object
#  4   SUBJETIVO            2907 non-null   object
#  5   OBJETIVO             2946 non-null   object
#  6   Concatenada          3000 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 164.2+ KB

# %%
#Ditribución de hc por sexo
historias_clinicas["SEXO"].value_counts()
px.histogram(historias_clinicas, 
             x="SEXO", 
             title="Distribución de Sexo en Historias Clínicas", 
             color="SEXO",
             text_auto=True)

# %%
#histrograma de edad
px.histogram(historias_clinicas, 
             x="EDAD", 
             title="Distribución de Edad en Historias Clínicas", 
            text_auto=True)

# %%
#Distribución de HC por edad y sexo
px.histogram(historias_clinicas, 
             x="EDAD", 
             title="Distribución de Edad en Historias Clínicas por Sexo", 
             color="SEXO",
             text_auto=True)

# %%
px.histogram(
    historias_clinicas,
    x="GRUPO",
    title="Distribución de Historias Clínicas por Grupo",
    color="GRUPO",
    text_auto=True
)

# %%
historias_clinicas
# Out:
#            SEXO  EDAD               GRUPO ESPECIALIDAD_MEDICA  \
# 0      Femenino    38    Otros trastornos          PSICOLOGÍA
# 1     Masculino    22  T. externalizantes          PSICOLOGÍA
# 2     Masculino     9    Otros trastornos          PSICOLOGÍA
# 3     Masculino    28    Otros trastornos          PSICOLOGÍA
# 4      Femenino     8    Otros trastornos          PSICOLOGÍA
# ...         ...   ...                 ...                 ...
# 2995  Masculino    29    Otros trastornos          PSICOLOGÍA
# 2996   Femenino    55       T. depresivos          PSICOLOGÍA
# 2997  Masculino     9     T. personalidad          PSICOLOGÍA
# 2998  Masculino    57    Otros trastornos          PSICOLOGÍA
# 2999  Masculino    57    Otros trastornos          PSICOLOGÍA
#
#                                               SUBJETIVO  \
# 0     Paciente refiere: "Me empezaron a dar como uno...
# 1     Paciente refiere "Me he sentido muy mal, en el...
# 2     La madre refiere "el viene por un acompañamien...
# 3     Paciente refiere "Estas cosas que han pasado m...
# 4     La madre refiere "Ella ha manifestado ciertas ...
# ...                                                 ...
# 2995  \n"yo estoy muy bien, no he vuelto a consumir,...
# 2996  Reporta dificultades de sueño, a pesar de toma...
# 2997  Paciente refiere:\n"A veces no controlo lo que...
# 2998  ‘’Lo mío es bastante duro, porque la enfermeda...
# 2999  La esposa Nubia Arroyave refiere:\n"En ocasion...
#
#                                                OBJETIVO  \
# 0     Paciente alerta, colaboradora con apariencia o...
# 1     Paciente a quien evaluó por primera vez, alert...
# 2                                                  None
# 3     Paciente quien evalúo por primera vez, alerta,...
# 4     Paciente ingresa en compañía de la madre, aler...
# ...                                                 ...
# 2995  \nToxicológicos: Marihuana y Perico hace 15 añ...
# 2996  Alerta, actitud adecuada, orientación en tiemp...
# 2997  Se realiza cita en la modalidad: Teleconsulta,...
# 2998  Paciente quien evalúo por primera vez, con bas...
# 2999  Alerta, actitud colabora en la entrevista, ori...
#
#                                             Concatenada
# 0     Paciente refiere: "Me empezaron a dar como uno...
# 1     Paciente refiere "Me he sentido muy mal, en el...
# 2     La madre refiere "el viene por un acompañamien...
# 3     Paciente refiere "Estas cosas que han pasado m...
# 4     La madre refiere "Ella ha manifestado ciertas ...
# ...                                                 ...
# 2995  \n"yo estoy muy bien, no he vuelto a consumir,...
# 2996  Reporta dificultades de sueño, a pesar de toma...
# 2997  Paciente refiere:\n"A veces no controlo lo que...
# 2998  ‘’Lo mío es bastante duro, porque la enfermeda...
# 2999  La esposa Nubia Arroyave refiere:\n"En ocasion...
#
# [3000 rows x 7 columns]
